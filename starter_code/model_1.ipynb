# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/moz/Library/Python/3.9/lib/python/site-packages (2.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: packaging in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: libclang>=13.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.62.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2024-03-01 10:29:14.308708: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/moz/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2.15.0

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
df = pd.get_dummies(df)
df
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0            -0.003520  ...          -0.096     0.927          0.105
# 1            -0.000581  ...          -0.176     0.868          0.233
# 2            -0.000115  ...          -0.168     0.791          0.201
# 3            -0.001130  ...          -0.210     1.046          0.334
# 4            -0.001900  ...          -0.229     0.972          0.315
# ...                ...  ...             ...       ...            ...
# 6986         -0.015700  ...          -0.189     1.088          0.313
# 6987         -0.000170  ...          -0.196     0.903          0.237
# 6988         -0.007690  ...          -0.224     1.031          0.341
# 6989         -0.002850  ...          -0.224     1.041          0.341
# 6990         -0.010800  ...          -0.216     1.193          0.410
#
#       koi_srad_err2         ra        dec  koi_kepmag  \
# 0            -0.061  291.93423  48.141651      15.347
# 1            -0.078  297.00482  48.134129      15.436
# 2            -0.067  285.53461  48.285210      15.597
# 3            -0.133  288.75488  48.226200      15.509
# 4            -0.105  296.28613  48.224670      15.714
# ...             ...        ...        ...         ...
# 6986         -0.228  298.74921  46.973351      14.478
# 6987         -0.079  297.18875  47.093819      14.082
# 6988         -0.114  286.50937  47.163219      14.757
# 6989         -0.114  294.16489  47.176281      15.385
# 6990         -0.137  297.00977  47.121021      14.826
#
#       koi_disposition_CANDIDATE  koi_disposition_CONFIRMED  \
# 0                         False                       True
# 1                         False                      False
# 2                         False                      False
# 3                         False                       True
# 4                         False                       True
# ...                         ...                        ...
# 6986                      False                      False
# 6987                      False                      False
# 6988                       True                      False
# 6989                      False                      False
# 6990                      False                      False
#
#       koi_disposition_FALSE POSITIVE
# 0                              False
# 1                               True
# 2                               True
# 3                              False
# 4                              False
# ...                              ...
# 6986                            True
# 6987                            True
# 6988                           False
# 6989                            True
# 6990                            True
#
# [6991 rows x 43 columns]

# %%
df = df.drop(columns=['koi_disposition_CANDIDATE','koi_disposition_FALSE POSITIVE'])
df
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0            -0.003520  ...      4.467           0.064          -0.096
# 1            -0.000581  ...      4.544           0.044          -0.176
# 2            -0.000115  ...      4.564           0.053          -0.168
# 3            -0.001130  ...      4.438           0.070          -0.210
# 4            -0.001900  ...      4.486           0.054          -0.229
# ...                ...  ...        ...             ...             ...
# 6986         -0.015700  ...      4.296           0.231          -0.189
# 6987         -0.000170  ...      4.529           0.035          -0.196
# 6988         -0.007690  ...      4.444           0.056          -0.224
# 6989         -0.002850  ...      4.447           0.056          -0.224
# 6990         -0.010800  ...      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  \
# 0        0.927          0.105         -0.061  291.93423  48.141651
# 1        0.868          0.233         -0.078  297.00482  48.134129
# 2        0.791          0.201         -0.067  285.53461  48.285210
# 3        1.046          0.334         -0.133  288.75488  48.226200
# 4        0.972          0.315         -0.105  296.28613  48.224670
# ...        ...            ...            ...        ...        ...
# 6986     1.088          0.313         -0.228  298.74921  46.973351
# 6987     0.903          0.237         -0.079  297.18875  47.093819
# 6988     1.031          0.341         -0.114  286.50937  47.163219
# 6989     1.041          0.341         -0.114  294.16489  47.176281
# 6990     1.193          0.410         -0.137  297.00977  47.121021
#
#       koi_kepmag  koi_disposition_CONFIRMED
# 0         15.347                       True
# 1         15.436                      False
# 2         15.597                      False
# 3         15.509                       True
# 4         15.714                       True
# ...          ...                        ...
# 6986      14.478                      False
# 6987      14.082                      False
# 6988      14.757                      False
# 6989      15.385                      False
# 6990      14.826                      False
#
# [6991 rows x 41 columns]

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
       'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
       'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
       'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
       'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
       'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
       'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
       'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
       'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
       'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
       'koi_kepmag']]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
X = selected_features
y = df[['koi_disposition_CONFIRMED']]
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991, 1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Split the data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
# Out:
# /Users/moz/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/moz/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/moz/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
### END SOLUTION

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4100
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 14402 (56.26 KB)
# Trainable params: 14402 (56.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 164/164 - 1s - loss: 0.4037 - accuracy: 0.7780 - 818ms/epoch - 5ms/step
# Epoch 2/60
# 164/164 - 0s - loss: 0.3409 - accuracy: 0.8133 - 157ms/epoch - 956us/step
# Epoch 3/60
# 164/164 - 0s - loss: 0.3286 - accuracy: 0.8272 - 154ms/epoch - 939us/step
# Epoch 4/60
# 164/164 - 0s - loss: 0.3191 - accuracy: 0.8373 - 158ms/epoch - 961us/step
# Epoch 5/60
# 164/164 - 0s - loss: 0.3172 - accuracy: 0.8339 - 156ms/epoch - 948us/step
# Epoch 6/60
# 164/164 - 0s - loss: 0.3094 - accuracy: 0.8428 - 153ms/epoch - 933us/step
# Epoch 7/60
# 164/164 - 0s - loss: 0.3027 - accuracy: 0.8499 - 153ms/epoch - 933us/step
# Epoch 8/60
# 164/164 - 0s - loss: 0.2947 - accuracy: 0.8606 - 154ms/epoch - 940us/step
# Epoch 9/60
# 164/164 - 0s - loss: 0.2965 - accuracy: 0.8594 - 153ms/epoch - 931us/step
# Epoch 10/60
# 164/164 - 0s - loss: 0.2933 - accuracy: 0.8598 - 153ms/epoch - 934us/step
# Epoch 11/60
# 164/164 - 0s - loss: 0.2825 - accuracy: 0.8655 - 152ms/epoch - 927us/step
# Epoch 12/60
# 164/164 - 0s - loss: 0.2832 - accuracy: 0.8688 - 151ms/epoch - 919us/step
# Epoch 13/60
# 164/164 - 0s - loss: 0.2805 - accuracy: 0.8655 - 153ms/epoch - 934us/step
# Epoch 14/60
# 164/164 - 0s - loss: 0.2733 - accuracy: 0.8722 - 153ms/epoch - 934us/step
# Epoch 15/60
# 164/164 - 0s - loss: 0.2711 - accuracy: 0.8770 - 153ms/epoch - 933us/step
# Epoch 16/60
# 164/164 - 0s - loss: 0.2701 - accuracy: 0.8716 - 152ms/epoch - 928us/step
# Epoch 17/60
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8703 - 152ms/epoch - 926us/step
# Epoch 18/60
# 164/164 - 0s - loss: 0.2678 - accuracy: 0.8783 - 152ms/epoch - 927us/step
# Epoch 19/60
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8690 - 157ms/epoch - 955us/step
# Epoch 20/60
# 164/164 - 0s - loss: 0.2647 - accuracy: 0.8764 - 164ms/epoch - 1000us/step
# Epoch 21/60
# 164/164 - 0s - loss: 0.2677 - accuracy: 0.8753 - 156ms/epoch - 950us/step
# Epoch 22/60
# 164/164 - 0s - loss: 0.2607 - accuracy: 0.8796 - 152ms/epoch - 929us/step
# Epoch 23/60
# 164/164 - 0s - loss: 0.2607 - accuracy: 0.8816 - 153ms/epoch - 931us/step
# Epoch 24/60
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8766 - 153ms/epoch - 935us/step
# Epoch 25/60
# 164/164 - 0s - loss: 0.2524 - accuracy: 0.8867 - 152ms/epoch - 929us/step
# Epoch 26/60
# 164/164 - 0s - loss: 0.2571 - accuracy: 0.8812 - 152ms/epoch - 928us/step
# Epoch 27/60
# 164/164 - 0s - loss: 0.2542 - accuracy: 0.8850 - 153ms/epoch - 936us/step
# Epoch 28/60
# 164/164 - 0s - loss: 0.2510 - accuracy: 0.8854 - 153ms/epoch - 936us/step
# Epoch 29/60
# 164/164 - 0s - loss: 0.2515 - accuracy: 0.8831 - 152ms/epoch - 928us/step
# Epoch 30/60
# 164/164 - 0s - loss: 0.2491 - accuracy: 0.8858 - 153ms/epoch - 935us/step
# Epoch 31/60
# 164/164 - 0s - loss: 0.2504 - accuracy: 0.8867 - 152ms/epoch - 928us/step
# Epoch 32/60
# 164/164 - 0s - loss: 0.2439 - accuracy: 0.8901 - 152ms/epoch - 928us/step
# Epoch 33/60
# 164/164 - 0s - loss: 0.2454 - accuracy: 0.8848 - 152ms/epoch - 930us/step
# Epoch 34/60
# 164/164 - 0s - loss: 0.2476 - accuracy: 0.8848 - 152ms/epoch - 924us/step
# Epoch 35/60
# 164/164 - 0s - loss: 0.2434 - accuracy: 0.8873 - 152ms/epoch - 928us/step
# Epoch 36/60
# 164/164 - 0s - loss: 0.2390 - accuracy: 0.8909 - 167ms/epoch - 1ms/step
# Epoch 37/60
# 164/164 - 0s - loss: 0.2380 - accuracy: 0.8930 - 152ms/epoch - 928us/step
# Epoch 38/60
# 164/164 - 0s - loss: 0.2378 - accuracy: 0.8936 - 152ms/epoch - 926us/step
# Epoch 39/60
# 164/164 - 0s - loss: 0.2392 - accuracy: 0.8875 - 152ms/epoch - 926us/step
# Epoch 40/60
# 164/164 - 0s - loss: 0.2407 - accuracy: 0.8896 - 156ms/epoch - 949us/step
# Epoch 41/60
# 164/164 - 0s - loss: 0.2347 - accuracy: 0.8928 - 155ms/epoch - 943us/step
# Epoch 42/60
# 164/164 - 0s - loss: 0.2349 - accuracy: 0.8949 - 153ms/epoch - 932us/step
# Epoch 43/60
# 164/164 - 0s - loss: 0.2335 - accuracy: 0.8911 - 152ms/epoch - 926us/step
# Epoch 44/60
# 164/164 - 0s - loss: 0.2341 - accuracy: 0.8913 - 152ms/epoch - 928us/step
# Epoch 45/60
# 164/164 - 0s - loss: 0.2265 - accuracy: 0.8962 - 153ms/epoch - 930us/step
# Epoch 46/60
# 164/164 - 0s - loss: 0.2312 - accuracy: 0.8936 - 155ms/epoch - 946us/step
# Epoch 47/60
# 164/164 - 0s - loss: 0.2386 - accuracy: 0.8894 - 157ms/epoch - 954us/step
# Epoch 48/60
# 164/164 - 0s - loss: 0.2295 - accuracy: 0.8936 - 153ms/epoch - 932us/step
# Epoch 49/60
# 164/164 - 0s - loss: 0.2288 - accuracy: 0.8959 - 152ms/epoch - 927us/step
# Epoch 50/60
# 164/164 - 0s - loss: 0.2239 - accuracy: 0.8997 - 153ms/epoch - 930us/step
# Epoch 51/60
# 164/164 - 0s - loss: 0.2343 - accuracy: 0.8941 - 152ms/epoch - 927us/step
# Epoch 52/60
# 164/164 - 0s - loss: 0.2340 - accuracy: 0.8909 - 152ms/epoch - 926us/step
# Epoch 53/60
# 164/164 - 0s - loss: 0.2272 - accuracy: 0.8955 - 158ms/epoch - 966us/step
# Epoch 54/60
# 164/164 - 0s - loss: 0.2228 - accuracy: 0.9010 - 160ms/epoch - 975us/step
# Epoch 55/60
# 164/164 - 0s - loss: 0.2229 - accuracy: 0.9012 - 154ms/epoch - 938us/step
# Epoch 56/60
# 164/164 - 0s - loss: 0.2266 - accuracy: 0.8945 - 154ms/epoch - 941us/step
# Epoch 57/60
# 164/164 - 0s - loss: 0.2263 - accuracy: 0.8924 - 165ms/epoch - 1ms/step
# Epoch 58/60
# 164/164 - 0s - loss: 0.2368 - accuracy: 0.8924 - 163ms/epoch - 995us/step
# Epoch 59/60
# 164/164 - 0s - loss: 0.2189 - accuracy: 0.9001 - 151ms/epoch - 921us/step
# Epoch 60/60
# 164/164 - 0s - loss: 0.2196 - accuracy: 0.9001 - 150ms/epoch - 917us/step

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2163 - accuracy: 0.9085 - 182ms/epoch - 3ms/step
# Normal Neural Network - Loss: 0.21628865599632263, Accuracy: 0.9084668159484863

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Assuming y is your target variable
yy = np.array(y).ravel()

# %%
# Create the GridSearchCV model
from sklearn.model_selection import train_test_split
X_trainn, X_testt, y_trainn, y_testt = train_test_split(X, yy, random_state=42)

# %%
# Train the model with GridSearch
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['linear','rbf']}
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_trainn, y_trainn)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(grid.best_params_)
#       2 print(grid.best_score_)
#
# NameError: name 'grid' is not defined

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
