# %%
pip install tensorflow
# Out:
# 226166.48s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.15.0-cp39-cp39-macosx_10_15_x86_64.whl (239.1 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Requirement already satisfied: packaging in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.2)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.62.0-cp39-cp39-macosx_10_10_universal2.whl (10.1 MB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.10.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 2.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.26.4)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.6-py2.py3-none-macosx_10_9_x86_64.whl (24.5 MB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting ml-dtypes~=0.2.0
#   Using cached ml_dtypes-0.2.0-cp39-cp39-macosx_10_9_universal2.whl (1.2 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Collecting tensorboard<2.16,>=2.15
#   Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Collecting tensorflow-estimator<2.16,>=2.15.0
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.36.0-cp39-cp39-macosx_10_14_x86_64.whl (2.5 MB)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Collecting flatbuffers>=23.5.26
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras<2.16,>=2.15.0
#   Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.28.1-py2.py3-none-any.whl (186 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.1 MB/s eta 0:00:011
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.5.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 3.1 MB/s eta 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 1.2 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<2,>=0.5
#   Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 841 kB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow) (3.17.0)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.0 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 3.0 MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp39-cp39-macosx_10_9_x86_64.whl (122 kB)
#      |████████████████████████████████| 122 kB 2.8 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 177 kB/s eta 0:00:011
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_x86_64.whl (14 kB)
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, certifi, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, MarkupSafe, google-auth, werkzeug, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, ml-dtypes, libclang, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.28.1 google-auth-oauthlib-1.2.0 google-pasta-0.2.0 grpcio-1.62.0 h5py-3.10.0 idna-3.6 keras-2.15.0 libclang-16.0.6 markdown-3.5.2 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.25.3 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.36.0 termcolor-2.4.0 urllib3-2.2.1 werkzeug-3.0.1 wrapt-1.14.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
df = pd.get_dummies(df)
df
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0            -0.003520  ...          -0.096     0.927          0.105
# 1            -0.000581  ...          -0.176     0.868          0.233
# 2            -0.000115  ...          -0.168     0.791          0.201
# 3            -0.001130  ...          -0.210     1.046          0.334
# 4            -0.001900  ...          -0.229     0.972          0.315
# ...                ...  ...             ...       ...            ...
# 6986         -0.015700  ...          -0.189     1.088          0.313
# 6987         -0.000170  ...          -0.196     0.903          0.237
# 6988         -0.007690  ...          -0.224     1.031          0.341
# 6989         -0.002850  ...          -0.224     1.041          0.341
# 6990         -0.010800  ...          -0.216     1.193          0.410
#
#       koi_srad_err2         ra        dec  koi_kepmag  \
# 0            -0.061  291.93423  48.141651      15.347
# 1            -0.078  297.00482  48.134129      15.436
# 2            -0.067  285.53461  48.285210      15.597
# 3            -0.133  288.75488  48.226200      15.509
# 4            -0.105  296.28613  48.224670      15.714
# ...             ...        ...        ...         ...
# 6986         -0.228  298.74921  46.973351      14.478
# 6987         -0.079  297.18875  47.093819      14.082
# 6988         -0.114  286.50937  47.163219      14.757
# 6989         -0.114  294.16489  47.176281      15.385
# 6990         -0.137  297.00977  47.121021      14.826
#
#       koi_disposition_CANDIDATE  koi_disposition_CONFIRMED  \
# 0                         False                       True
# 1                         False                      False
# 2                         False                      False
# 3                         False                       True
# 4                         False                       True
# ...                         ...                        ...
# 6986                      False                      False
# 6987                      False                      False
# 6988                       True                      False
# 6989                      False                      False
# 6990                      False                      False
#
#       koi_disposition_FALSE POSITIVE
# 0                              False
# 1                               True
# 2                               True
# 3                              False
# 4                              False
# ...                              ...
# 6986                            True
# 6987                            True
# 6988                           False
# 6989                            True
# 6990                            True
#
# [6991 rows x 43 columns]

# %%
df = df.drop(columns=['koi_disposition_CANDIDATE','koi_disposition_FALSE POSITIVE'])
df
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0            -0.003520  ...      4.467           0.064          -0.096
# 1            -0.000581  ...      4.544           0.044          -0.176
# 2            -0.000115  ...      4.564           0.053          -0.168
# 3            -0.001130  ...      4.438           0.070          -0.210
# 4            -0.001900  ...      4.486           0.054          -0.229
# ...                ...  ...        ...             ...             ...
# 6986         -0.015700  ...      4.296           0.231          -0.189
# 6987         -0.000170  ...      4.529           0.035          -0.196
# 6988         -0.007690  ...      4.444           0.056          -0.224
# 6989         -0.002850  ...      4.447           0.056          -0.224
# 6990         -0.010800  ...      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  \
# 0        0.927          0.105         -0.061  291.93423  48.141651
# 1        0.868          0.233         -0.078  297.00482  48.134129
# 2        0.791          0.201         -0.067  285.53461  48.285210
# 3        1.046          0.334         -0.133  288.75488  48.226200
# 4        0.972          0.315         -0.105  296.28613  48.224670
# ...        ...            ...            ...        ...        ...
# 6986     1.088          0.313         -0.228  298.74921  46.973351
# 6987     0.903          0.237         -0.079  297.18875  47.093819
# 6988     1.031          0.341         -0.114  286.50937  47.163219
# 6989     1.041          0.341         -0.114  294.16489  47.176281
# 6990     1.193          0.410         -0.137  297.00977  47.121021
#
#       koi_kepmag  koi_disposition_CONFIRMED
# 0         15.347                       True
# 1         15.436                      False
# 2         15.597                      False
# 3         15.509                       True
# 4         15.714                       True
# ...          ...                        ...
# 6986      14.478                      False
# 6987      14.082                      False
# 6988      14.757                      False
# 6989      15.385                      False
# 6990      14.826                      False
#
# [6991 rows x 41 columns]

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
       'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
       'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
       'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
       'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
       'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
       'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
       'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
       'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
       'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
       'koi_kepmag']]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
X = selected_features
y = df[['koi_disposition_CONFIRMED']]
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991, 1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Split the data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
# Out:
# /Users/moz/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/moz/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Users/moz/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %% [markdown]
# # Train the Model

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
### END SOLUTION

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 100)               4100
#
#  dense_8 (Dense)             (None, 100)               10100
#
#  dense_9 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 14402 (56.26 KB)
# Trainable params: 14402 (56.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 164/164 - 2s - loss: 0.4065 - accuracy: 0.7746 - 2s/epoch - 13ms/step
# Epoch 2/60
# 164/164 - 0s - loss: 0.3335 - accuracy: 0.8238 - 312ms/epoch - 2ms/step
# Epoch 3/60
# 164/164 - 0s - loss: 0.3189 - accuracy: 0.8413 - 283ms/epoch - 2ms/step
# Epoch 4/60
# 164/164 - 0s - loss: 0.3160 - accuracy: 0.8379 - 258ms/epoch - 2ms/step
# Epoch 5/60
# 164/164 - 0s - loss: 0.3086 - accuracy: 0.8440 - 269ms/epoch - 2ms/step
# Epoch 6/60
# 164/164 - 0s - loss: 0.3034 - accuracy: 0.8512 - 266ms/epoch - 2ms/step
# Epoch 7/60
# 164/164 - 0s - loss: 0.3109 - accuracy: 0.8455 - 255ms/epoch - 2ms/step
# Epoch 8/60
# 164/164 - 0s - loss: 0.2979 - accuracy: 0.8547 - 263ms/epoch - 2ms/step
# Epoch 9/60
# 164/164 - 0s - loss: 0.2952 - accuracy: 0.8552 - 268ms/epoch - 2ms/step
# Epoch 10/60
# 164/164 - 0s - loss: 0.2891 - accuracy: 0.8600 - 261ms/epoch - 2ms/step
# Epoch 11/60
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8625 - 255ms/epoch - 2ms/step
# Epoch 12/60
# 164/164 - 0s - loss: 0.2852 - accuracy: 0.8636 - 264ms/epoch - 2ms/step
# Epoch 13/60
# 164/164 - 0s - loss: 0.2780 - accuracy: 0.8728 - 255ms/epoch - 2ms/step
# Epoch 14/60
# 164/164 - 0s - loss: 0.2812 - accuracy: 0.8688 - 396ms/epoch - 2ms/step
# Epoch 15/60
# 164/164 - 0s - loss: 0.2718 - accuracy: 0.8768 - 258ms/epoch - 2ms/step
# Epoch 16/60
# 164/164 - 0s - loss: 0.2694 - accuracy: 0.8779 - 331ms/epoch - 2ms/step
# Epoch 17/60
# 164/164 - 0s - loss: 0.2757 - accuracy: 0.8684 - 257ms/epoch - 2ms/step
# Epoch 18/60
# 164/164 - 0s - loss: 0.2716 - accuracy: 0.8749 - 248ms/epoch - 2ms/step
# Epoch 19/60
# 164/164 - 0s - loss: 0.2658 - accuracy: 0.8800 - 293ms/epoch - 2ms/step
# Epoch 20/60
# 164/164 - 0s - loss: 0.2627 - accuracy: 0.8806 - 354ms/epoch - 2ms/step
# Epoch 21/60
# 164/164 - 0s - loss: 0.2668 - accuracy: 0.8777 - 299ms/epoch - 2ms/step
# Epoch 22/60
# 164/164 - 0s - loss: 0.2541 - accuracy: 0.8856 - 244ms/epoch - 1ms/step
# Epoch 23/60
# 164/164 - 0s - loss: 0.2636 - accuracy: 0.8777 - 256ms/epoch - 2ms/step
# Epoch 24/60
# 164/164 - 0s - loss: 0.2564 - accuracy: 0.8846 - 247ms/epoch - 2ms/step
# Epoch 25/60
# 164/164 - 0s - loss: 0.2525 - accuracy: 0.8858 - 247ms/epoch - 2ms/step
# Epoch 26/60
# 164/164 - 0s - loss: 0.2529 - accuracy: 0.8859 - 243ms/epoch - 1ms/step
# Epoch 27/60
# 164/164 - 0s - loss: 0.2508 - accuracy: 0.8867 - 252ms/epoch - 2ms/step
# Epoch 28/60
# 164/164 - 0s - loss: 0.2611 - accuracy: 0.8768 - 260ms/epoch - 2ms/step
# Epoch 29/60
# 164/164 - 0s - loss: 0.2449 - accuracy: 0.8911 - 246ms/epoch - 1ms/step
# Epoch 30/60
# 164/164 - 0s - loss: 0.2486 - accuracy: 0.8892 - 254ms/epoch - 2ms/step
# Epoch 31/60
# 164/164 - 0s - loss: 0.2489 - accuracy: 0.8840 - 243ms/epoch - 1ms/step
# Epoch 32/60
# 164/164 - 0s - loss: 0.2448 - accuracy: 0.8880 - 257ms/epoch - 2ms/step
# Epoch 33/60
# 164/164 - 0s - loss: 0.2481 - accuracy: 0.8840 - 271ms/epoch - 2ms/step
# Epoch 34/60
# 164/164 - 0s - loss: 0.2398 - accuracy: 0.8915 - 257ms/epoch - 2ms/step
# Epoch 35/60
# 164/164 - 0s - loss: 0.2395 - accuracy: 0.8903 - 260ms/epoch - 2ms/step
# Epoch 36/60
# 164/164 - 0s - loss: 0.2438 - accuracy: 0.8886 - 264ms/epoch - 2ms/step
# Epoch 37/60
# 164/164 - 0s - loss: 0.2375 - accuracy: 0.8924 - 261ms/epoch - 2ms/step
# Epoch 38/60
# 164/164 - 0s - loss: 0.2373 - accuracy: 0.8924 - 244ms/epoch - 1ms/step
# Epoch 39/60
# 164/164 - 0s - loss: 0.2403 - accuracy: 0.8938 - 245ms/epoch - 1ms/step
# Epoch 40/60
# 164/164 - 0s - loss: 0.2370 - accuracy: 0.8919 - 242ms/epoch - 1ms/step
# Epoch 41/60
# 164/164 - 0s - loss: 0.2323 - accuracy: 0.8945 - 250ms/epoch - 2ms/step
# Epoch 42/60
# 164/164 - 0s - loss: 0.2411 - accuracy: 0.8884 - 244ms/epoch - 1ms/step
# Epoch 43/60
# 164/164 - 0s - loss: 0.2369 - accuracy: 0.8875 - 242ms/epoch - 1ms/step
# Epoch 44/60
# 164/164 - 0s - loss: 0.2389 - accuracy: 0.8882 - 255ms/epoch - 2ms/step
# Epoch 45/60
# 164/164 - 0s - loss: 0.2322 - accuracy: 0.8947 - 245ms/epoch - 1ms/step
# Epoch 46/60
# 164/164 - 0s - loss: 0.2298 - accuracy: 0.8989 - 271ms/epoch - 2ms/step
# Epoch 47/60
# 164/164 - 0s - loss: 0.2296 - accuracy: 0.8930 - 249ms/epoch - 2ms/step
# Epoch 48/60
# 164/164 - 0s - loss: 0.2302 - accuracy: 0.8974 - 259ms/epoch - 2ms/step
# Epoch 49/60
# 164/164 - 0s - loss: 0.2278 - accuracy: 0.8987 - 260ms/epoch - 2ms/step
# Epoch 50/60
# 164/164 - 0s - loss: 0.2298 - accuracy: 0.8951 - 292ms/epoch - 2ms/step
# Epoch 51/60
# 164/164 - 0s - loss: 0.2223 - accuracy: 0.8997 - 250ms/epoch - 2ms/step
# Epoch 52/60
# 164/164 - 0s - loss: 0.2268 - accuracy: 0.8957 - 299ms/epoch - 2ms/step
# Epoch 53/60
# 164/164 - 0s - loss: 0.2279 - accuracy: 0.8953 - 272ms/epoch - 2ms/step
# Epoch 54/60
# 164/164 - 0s - loss: 0.2248 - accuracy: 0.8955 - 260ms/epoch - 2ms/step
# Epoch 55/60
# 164/164 - 0s - loss: 0.2270 - accuracy: 0.8943 - 265ms/epoch - 2ms/step
# Epoch 56/60
# 164/164 - 0s - loss: 0.2208 - accuracy: 0.9001 - 308ms/epoch - 2ms/step
# Epoch 57/60
# 164/164 - 0s - loss: 0.2223 - accuracy: 0.8980 - 269ms/epoch - 2ms/step
# Epoch 58/60
# 164/164 - 0s - loss: 0.2250 - accuracy: 0.8968 - 251ms/epoch - 2ms/step
# Epoch 59/60
# 164/164 - 0s - loss: 0.2210 - accuracy: 0.8981 - 251ms/epoch - 2ms/step
# Epoch 60/60
# 164/164 - 0s - loss: 0.2222 - accuracy: 0.8999 - 257ms/epoch - 2ms/step

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2203 - accuracy: 0.9062 - 278ms/epoch - 5ms/step
# Normal Neural Network - Loss: 0.2202998697757721, Accuracy: 0.9061784744262695

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

# %%
# Train the model with GridSearch

# %%
print(grid2.best_params_)
print(grid2.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
